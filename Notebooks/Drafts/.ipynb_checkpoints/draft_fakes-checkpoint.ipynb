# %%
# %matplotlib notebook
import numpy as np
import scipy as sp
import pandas
import matplotlib.pyplot as plt
import os

# %%
from astrobject import photometry
from astropy import units
from astrobject import baseobject

# %%
FILE_IN = "/Users/mart1/Desktop/DATA/ZTF/ztf_20181006408484_000695_zr_c12_o_q2_sciimg.fits"

sn_ra, sn_dec = 8.1570973, 41.31573905

# %%
sn_target = baseobject.get_target(name="SN_test", ra=sn_ra, dec=sn_dec)

# %%
ztfimg = photometry.Image(FILE_IN, background=0)

# %%
ztfimg.set_target(sn_target)

# %%
ztfimg.show()
# Out:
# <img src="data:image/png;base64,..." width="599.5">
# /Users/mart1/anaconda3/lib/python3.7/site-packages/astrobject-0.8.6-py3.7.egg/astrobject/photometry.py:1513: RuntimeWarning: invalid value encountered in log10
# {'figure': <Figure size 600x500 with 1 Axes>,
#  'ax': <matplotlib.axes._axes.Axes at 0x8379fc390>,
#  'imshow': <matplotlib.image.AxesImage at 0x8379fca50>,
#  'prop': {'interpolation': 'nearest',
#   'origin': 'lower',
#   'cmap': <matplotlib.colors.ListedColormap at 0x11886f590>,
#   'vmax': 2.32291550075625,
#   'vmin': 2.0870462415915783},
#  'target_plot': [<matplotlib.lines.Line2D at 0x837af5650>]}

# %%
ztfimg.show(zoomon="target")
# Out:
# <img src="data:image/png;base64,..." width="599.5">
# /Users/mart1/anaconda3/lib/python3.7/site-packages/astrobject-0.8.6-py3.7.egg/astrobject/photometry.py:1513: RuntimeWarning: invalid value encountered in log10
# {'figure': <Figure size 600x500 with 1 Axes>,
#  'ax': <matplotlib.axes._axes.Axes at 0x8378de8d0>,
#  'imshow': <matplotlib.image.AxesImage at 0x83771c810>,
#  'prop': {'interpolation': 'nearest',
#   'origin': 'lower',
#   'cmap': <matplotlib.colors.ListedColormap at 0x11886f590>,
#   'vmax': 2.32291550075625,
#   'vmin': 2.0870462415915783},
#  'target_plot': [<matplotlib.lines.Line2D at 0x136929b50>]}

# %%
ztfimg.download_catalogue("gaia")

# %%
ztfimg.show(show_catalogue=True, zoomon="target")
# Out:
# <img src="data:image/png;base64,..." width="599.5">
# /Users/mart1/anaconda3/lib/python3.7/site-packages/astrobject-0.8.6-py3.7.egg/astrobject/photometry.py:1513: RuntimeWarning: invalid value encountered in log10
# {'figure': <Figure size 600x500 with 1 Axes>,
#  'ax': <matplotlib.axes._axes.Axes at 0x837b63490>,
#  'imshow': <matplotlib.image.AxesImage at 0x8377c4fd0>,
#  'prop': {'interpolation': 'nearest',
#   'origin': 'lower',
#   'cmap': <matplotlib.colors.ListedColormap at 0x11886f590>,
#   'vmax': 2.32291550075625,
#   'vmin': 2.0870462415915783},
#  'target_plot': [<matplotlib.lines.Line2D at 0x837d2bc10>]}

# %%
ztfimg.catalogue.define_around(15*units.arcsec)

# %%
ztfimg.catalogue.ra
# Out:
# array([7.99323598, 7.9936826 , 8.13162261, ..., 7.88241421, 7.88873528,
#        7.91051051])

# %%
ztfimg.catalogue.sky_radec.search_around_sky(ztfimg.catalogue.sky_radec, 15*units.arcsec)
# Out:
# (array([   0,    1,    2, ..., 9252, 9253, 9253]),
#  array([   0,    1,    2, ..., 9252, 9249, 9253]),
#  <Angle [0.       , 0.       , 0.       , ..., 0.       , 0.0040474,
#          0.       ] deg>,
#  <Quantity [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#             0.00000000e+00, 7.06404245e-05, 0.00000000e+00]>)
